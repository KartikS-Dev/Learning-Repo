# %% [markdown]
# # <font size='10' color='#1ABC9C'>  Testing The Assumptions </font>

# %% [markdown]
# ### Statistical Summary of the standardized , feature engineered data after the handling of the outliers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline 
## When using the 'inline' backend, 
## your matplotlib graphs will be included in your notebook, next to the code.
import seaborn as sns
from scipy.stats import shapiro
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('dataset_cleaned.csv')
dataset.shape
# Out:
# (4506, 16)

# %%
corr = dataset.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1f07e_row0_col0, #T_1f07e_row1_col1, #T_1f07e_row2_col2, #T_1f07e_row3_col3, #T_1f07e_row4_col4, #T_1f07e_row5_col5, #T_1f07e_row6_col6, #T_1f07e_row7_col7, #T_1f07e_row8_col8, #T_1f07e_row9_col9, #T_1f07e_row10_col10, #T_1f07e_row11_col11, #T_1f07e_row12_col12, #T_1f07e_row13_col13, #T_1f07e_row14_col14, #T_1f07e_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col1, #T_1f07e_row8_col15, #T_1f07e_row9_col15, #T_1f07e_row13_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col3, #T_1f07e_row4_col15, #T_1f07e_row15_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col4, #T_1f07e_row1_col4, #T_1f07e_row10_col3, #T_1f07e_row10_col15, #T_1f07e_row15_col5, #T_1f07e_row15_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col5, #T_1f07e_row14_col2, #T_1f07e_row14_col3, #T_1f07e_row14_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col6, #T_1f07e_row0_col10, #T_1f07e_row6_col0, #T_1f07e_row6_col2, #T_1f07e_row6_col7, #T_1f07e_row6_col8, #T_1f07e_row6_col9, #T_1f07e_row12_col1, #T_1f07e_row12_col3, #T_1f07e_row12_col4, #T_1f07e_row12_col5, #T_1f07e_row12_col8, #T_1f07e_row12_col11, #T_1f07e_row12_col13, #T_1f07e_row12_col14, #T_1f07e_row12_col15, #T_1f07e_row14_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1f07e_row0_col8, #T_1f07e_row15_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col9 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col11, #T_1f07e_row15_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1f07e_row0_col12, #T_1f07e_row1_col9, #T_1f07e_row2_col13 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col13, #T_1f07e_row11_col6, #T_1f07e_row13_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1f07e_row0_col14, #T_1f07e_row2_col4, #T_1f07e_row11_col15 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_1f07e_row0_col15, #T_1f07e_row8_col5, #T_1f07e_row15_col13 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col0, #T_1f07e_row5_col12 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col3, #T_1f07e_row3_col13, #T_1f07e_row8_col13, #T_1f07e_row9_col3, #T_1f07e_row10_col2, #T_1f07e_row10_col14 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1f07e_row1_col5, #T_1f07e_row3_col12, #T_1f07e_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col6, #T_1f07e_row4_col0, #T_1f07e_row4_col9, #T_1f07e_row8_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1f07e_row1_col7, #T_1f07e_row2_col15, #T_1f07e_row13_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col8, #T_1f07e_row13_col14 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col10, #T_1f07e_row2_col10, #T_1f07e_row14_col10, #T_1f07e_row15_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col11, #T_1f07e_row7_col5, #T_1f07e_row7_col13, #T_1f07e_row8_col12, #T_1f07e_row13_col9 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_1f07e_row1_col12, #T_1f07e_row13_col15 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_1f07e_row1_col13 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_1f07e_row1_col14 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_1f07e_row1_col15, #T_1f07e_row2_col7 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_1f07e_row2_col0 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_1f07e_row2_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1f07e_row2_col3, #T_1f07e_row3_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1f07e_row2_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1f07e_row2_col6, #T_1f07e_row6_col11, #T_1f07e_row9_col10, #T_1f07e_row12_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1f07e_row2_col8, #T_1f07e_row7_col8, #T_1f07e_row13_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1f07e_row2_col9, #T_1f07e_row9_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1f07e_row2_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1f07e_row2_col12, #T_1f07e_row12_col2, #T_1f07e_row12_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1f07e_row2_col14, #T_1f07e_row6_col15, #T_1f07e_row11_col12 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1f07e_row3_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1f07e_row3_col1, #T_1f07e_row5_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1f07e_row3_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1f07e_row3_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_1f07e_row3_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_1f07e_row3_col6, #T_1f07e_row7_col12, #T_1f07e_row9_col14, #T_1f07e_row11_col13, #T_1f07e_row13_col0, #T_1f07e_row14_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1f07e_row3_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1f07e_row3_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1f07e_row3_col10, #T_1f07e_row11_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1f07e_row3_col11, #T_1f07e_row11_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_1f07e_row3_col14, #T_1f07e_row5_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_1f07e_row3_col15, #T_1f07e_row6_col12, #T_1f07e_row6_col13, #T_1f07e_row8_col6, #T_1f07e_row10_col9, #T_1f07e_row10_col12, #T_1f07e_row10_col13, #T_1f07e_row15_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1f07e_row4_col1, #T_1f07e_row7_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1f07e_row4_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1f07e_row4_col3, #T_1f07e_row5_col4 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_1f07e_row4_col5 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_1f07e_row4_col6, #T_1f07e_row11_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1f07e_row4_col7, #T_1f07e_row4_col14, #T_1f07e_row6_col1, #T_1f07e_row9_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_1f07e_row4_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1f07e_row4_col10, #T_1f07e_row10_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1f07e_row4_col11 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_1f07e_row4_col12, #T_1f07e_row10_col1, #T_1f07e_row12_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1f07e_row4_col13, #T_1f07e_row5_col13 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1f07e_row5_col1, #T_1f07e_row5_col7, #T_1f07e_row5_col14, #T_1f07e_row7_col11 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1f07e_row5_col2, #T_1f07e_row11_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_1f07e_row5_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_1f07e_row5_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_1f07e_row5_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_1f07e_row5_col10, #T_1f07e_row13_col5, #T_1f07e_row14_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_1f07e_row5_col11 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_1f07e_row5_col15, #T_1f07e_row9_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1f07e_row6_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1f07e_row6_col4, #T_1f07e_row8_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1f07e_row6_col5, #T_1f07e_row14_col5, #T_1f07e_row15_col14 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_1f07e_row6_col10, #T_1f07e_row7_col10, #T_1f07e_row8_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_1f07e_row6_col14, #T_1f07e_row15_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1f07e_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_1f07e_row7_col1, #T_1f07e_row9_col4, #

# %% [markdown]
# Finding Correlation between each Independent Variable

# %%
# getting a list of independent features
list_Indpndt_features = [feature for feature in dataset.columns if 'income' not in feature ]
list_Indpndt_features
# Out:
# ['age',
#  'yrsed',
#  'yrsempl',
#  'creddebt',
#  'othdebt',
#  'default',
#  'jobsat',
#  'homeown',
#  'address',
#  'cars',
#  'carvalue',
#  '2',
#  '3',
#  '4',
#  '5']

# %%
for i in range (0,len(list_Indpndt_features)):
    for j in range (i+1 , len(list_Indpndt_features)):
        correlation  = dataset[list_Indpndt_features[i]].corr(dataset[list_Indpndt_features[j]])
        if (correlation>=0.5):
            print( list_Indpndt_features[i],' & ', list_Indpndt_features[j] , " = " , correlation)
# Out:
# age  &  yrsempl  =  0.7122762051991901
# age  &  address  =  0.8215006220868258
# yrsed  &  4  =  0.5407862682826589
# yrsed  &  5  =  0.5080539369562193
# yrsempl  &  jobsat  =  0.5036322375274156
# yrsempl  &  address  =  0.6111167086766641
# creddebt  &  othdebt  =  0.6004922445818441
# creddebt  &  carvalue  =  0.5302796415475242
# othdebt  &  carvalue  =  0.6048845609610074

# %% [markdown]
# ## Assumption 1 :- Assumptions of Dependent and Independent Features
# ####        Null Hypothesis 1 : - The Independent features are Highly corelated with each other

# %% [markdown]
# we consider , correlation >=0.5 as high, therefore for those feature we'll fail to reject the Null hypothesis(HO)
#
# age  &  yrsempl  =  0.7122762051991901
#
# age  &  address  =  0.8215006220868258
#
# yrsed  &  4  =  0.5407862682826589
#
# yrsed  &  5  =  0.5080539369562193
#
# yrsempl  &  jobsat  =  0.5036322375274156
#
# yrsempl  &  address  =  0.6111167086766641
#
# creddebt  &  othdebt  =  0.6004922445818441
#
# creddebt  &  carvalue  =  0.5302796415475242
#
# othdebt  &  carvalue  =  0.6048845609610074
#
#
# ##
# ####        Null Hypothesis 2 :-  The Independent features are Highly Multi-Correleted
# To verify this we'll  check VIF for each feature , if VIF >10 , therefore that feature is highly multicorelated

# %%
## Reference : -https://www.geeksforgeeks.org/detecting-multicollinearity-with-vif-python/

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame() 
vif_data["feature"] =dataset[list_Indpndt_features].columns
  
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(dataset[list_Indpndt_features].values, i)
                          for i in range(len(dataset[list_Indpndt_features].columns))]
  
print(vif_data)
# Out:
#      feature        VIF
# 0        age  32.790978
# 1      yrsed  57.512400
# 2    yrsempl   8.628853
# 3   creddebt   6.511785
# 4    othdebt   8.012472
# 5    default   1.718354
# 6     jobsat   7.638147
# 7    homeown   2.901169
# 8    address   9.093785
# 9       cars   5.111536
# 10  carvalue  12.639053
# 11         2   4.474943
# 12         3   4.731309
# 13         4   7.287184
# 14         5   4.123552

# %% [markdown]
# ##### age ,yrsed and carvalue have high multi colinearity , thus for these features we fail to reject Null Hypothesis 2

# %% [markdown]
# Now we'll check correlation of Multicorrelated variables with Dependent Variable , and drop those have least correlation , they won't be useful for prediction.

# %%
target_features= [feature for feature in dataset.columns if 'yrsed' in feature or 'age' in feature or'carvalue' in feature ]
for i in range (0,len(target_features)):
        correlation  = dataset['income'].corr(dataset[target_features[i]])
        print( 'income' ,' & ', target_features[i] , " = " , correlation)
# Out:
# income  &  age  =  0.12833155470874583
# income  &  yrsed  =  0.19798343138251495
# income  &  carvalue  =  0.8893470860662386

# %% [markdown]
# ##### We can drop age and yrsed as it has least co-relation with income and wont be much helpful in prediction the same

# %%
## droping edcat. edcat2, edcat3 and  edcat4 
dataset=dataset.drop(['age'],axis=1)
dataset=dataset.drop(['yrsed'],axis=1)

dataset.head()
# Out:
#    yrsempl    income  creddebt   othdebt  default  jobsat  homeown  address  \
# 0      4.0  2.252303  0.387607  1.294482        0       4        1       22
# 1     15.0  2.029856  0.387607  0.982326        0       3        1       28
# 2      7.0  1.836011  0.387607  0.982326        0       5        0       21
# 3     15.0  2.214519  0.387607  0.982326        0       4        0       11
# 4      8.0  2.704247  0.387607  0.982326        0       3        0       11
#
#    cars  carvalue  2  3  4  5
# 0     1      11.3  0  0  0  0
# 1     1      11.3  0  0  0  0
# 2     1      11.3  0  0  0  0
# 3     1      11.3  0  0  0  0
# 4     1      22.1  0  0  0  0

# %% [markdown]
# #### Null Hypothesis 3  : - Multivariate normality exists
# We will use :
#     The Henze-Zirkler Multivariate Normality Test determines whether or not a group of variables follows a multivariate normal distribution. The null and alternative hypotheses for the test are as follows:
#
# H0 (null): The variables follow a multivariate normal distribution.
#
# Ha (alternative): The variables do not follow a multivariate normal distribution.
#
# reference : -https://www.statology.org/multivariate-normality-test-python/

# %%
from pingouin import multivariate_normality
multivariate_normality(dataset , alpha =0.05)
# Out:
# HZResults(hz=3.2398029484367545, pval=0.0, normal=False)

# %% [markdown]
# #### p-value is less than the alpha =0.05 , thus we to reject the H0
#
# also confirmed the test by verifying Mahalonobis distance in SPSS.

# %% [markdown]
# #### Null Hypothesis 4 :- Independent Variables are normally Distributed

# %%
'''
list_feature_forBOXCOX = [feature for feature in X_train.columns if 'homeown' not in feature
                          and'edcat5' not in feature
                         and 'default' not in feature
                          and 'jobsat' not in feature]

list_feature_forBOXCOX


### Apply box-Cox Transformation.

 # to make age normalwe will apply box-cox transformation
## Reference :-https://towardsdatascience.com/is-normal-distribution-necessary-in-regression-how-to-track-and-fix-it-494105bc50dd
from scipy import stats    

#transform the data using box-cox
for feature in list_feature_forBOXCOX:
    X_train[feature], lambd = stats.boxcox(X_train[feature])
    #plot the distribution curve and QQ-plot for transformed data
    sns.distplot(X_train[feature])
    plt.show()
    fig = sm.qqplot(X_train[feature],line='s')
    plt.show()
'''
# Out:
# "\nlist_feature_forBOXCOX = [feature for feature in X_train.columns if 'homeown' not in feature\n                          and'edcat5' not in feature\n                         and 'default' not in feature\n                          and 'jobsat' not in feature]\n\nlist_feature_forBOXCOX\n\n\n### Apply box-Cox Transformation.\n\n # to make age normalwe will apply box-cox transformation\n## Reference :-https://towardsdatascience.com/is-normal-distribution-necessary-in-regression-how-to-track-and-fix-it-494105bc50dd\nfrom scipy import stats    \n\n#transform the data using box-cox\nfor feature in list_feature_forBOXCOX:\n    X_train[feature], lambd = stats.boxcox(X_train[feature])\n    #plot the distribution curve and QQ-plot for transformed data\n    sns.distplot(X_train[feature])\n    plt.show()\n    fig = sm.qqplot(X_train[feature],line='s')\n    plt.show()\n"

# %% [markdown]
# ###### Checking the normality of all variables

# %%
for feature in dataset.columns:
    stat,p = shapiro(dataset[feature])
    print("\n For ",feature)
    if (p>0.05):
        print('we assume the distribution of our variable is normal/gaussian as P-value = ',p)
    else:
        print('we assume the distribution of our variable is NOT normal/gaussian as P-Value = ',p)
# Out:
#  For  yrsempl
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  income
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  2.2897458928916592e-10
#
#  For  creddebt
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  othdebt
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  default
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  jobsat
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  homeown
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  address
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  3.0689907732101035e-39
#
#  For  cars
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  carvalue
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  2
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  3
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  4
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0
#
#  For  5
# we assume the distribution of our variable is NOT normal/gaussian as P-Value =  0.0

# %% [markdown]
# #### Null Hypothesis 5 :- There is Homoscedacity among the data

# %%
### we are majorly looking at continuous variables only, ignore categorical features
list_columns = [feature for feature in dataset.columns if 'income' not in feature]

for column in list_columns:
    plt.scatter(dataset[column],dataset['income'])
    plt.xlabel(column)
    plt.ylabel('income')
    plt.title(column)
    plt.show()

# %% [markdown]
# #### No models show signs of Hetrosedacity , hence we don't have sufficient evidence to reject the null hypothesis 5

# %% [markdown]
# # Now We are ready to move to Feature Selection.

# %%
dataset.to_csv('dataset_cleaned_assumption_OK.csv',index=False)
